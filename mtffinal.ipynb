# %% [markdown]
# Final MTF Code Base

# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn import preprocessing

# %% [markdown]
# Financial Data Fetching/Formatting

# %% [markdown]
# You wanna pairplot? I wanna pairplot

# %%
fd20 = pd.read_excel(r"C:\Users\thewa\Downloads\hadr-20.xlsx")
fd20 = fd20.loc[(fd20["DAY_PER"] == 366) & (fd20["TYPE_HOSP"] != "Kaiser") & (fd20["ALOS_ALL"] != 0)].reset_index(drop = True)

fd19 = pd.read_excel(r"C:\Users\thewa\Downloads\hadr-19 (1).xlsx")
fd19 = fd19.loc[(fd19["DAY_PER"] == 366) & (fd19["TYPE_HOSP"] != "Kaiser") & (fd19["ALOS_ALL"] != 0)].reset_index(drop = True)

fd18 = pd.read_excel(r"C:\Users\thewa\Downloads\hadr-18.xlsx")
fd18 = fd18.loc[(fd18["DAY_PER"] == 366) & (fd18["TYPE_HOSP"] != "Kaiser") & (fd18["ALOS_ALL"] != 0)].reset_index(drop = True)

fd17 = pd.read_excel(r"C:\Users\thewa\Downloads\hadr-17.xlsx")
fd17 = fd17.loc[(fd17["DAY_PER"] == 366) & (fd17["TYPE_HOSP"] != "Kaiser") & (fd17["ALOS_ALL"] != 0)].reset_index(drop = True)

fd16 = pd.read_excel(r"C:\Users\thewa\Downloads\hadf16-_092018.xlsx")
fd16 = fd16.loc[(fd16["DAY_PER"] == 366) & (fd16["TYPE_HOSP"] != "Kaiser") & (fd16["ALOS_ALL"] != 0)].reset_index(drop = True)

fd15 = pd.read_excel(r"C:\Users\thewa\Downloads\hafd15-32018-extract.xlsx")
fd15 = fd15.loc[(fd15["DAY_PER"] == 366) & (fd15["TYPE_HOSP"] != "Kaiser") & (fd15["ALOS_ALL"] != 0)].reset_index(drop = True)

fd14 = pd.read_excel(r"C:\Users\thewa\Downloads\hafd14-42017-extract.xlsx")
fd14 = fd14.loc[(fd14["DAY_PER"] == 366) & (fd14["TYPE_HOSP"] != "Kaiser") & (fd14["ALOS_ALL"] != 0)].reset_index(drop = True)

fd13 = pd.read_excel(r"C:\Users\thewa\Downloads\hafd13-92015-extract.xls")
fd13 = fd13.loc[(fd13["DAY_PER"] == 366) & (fd13["TYPE_HOSP"] != "Kaiser") & (fd13["ALOS_ALL"] != 0)].reset_index(drop = True)

fd12 = pd.read_excel(r"C:\Users\thewa\Downloads\hafd12-10-2014-extract.xls")
fd12 = fd12.loc[(fd12["DAY_PER"] == 366) & (fd12["TYPE_HOSP"] != "Kaiser") & (fd12["ALOS_ALL"] != 0)].reset_index(drop = True)

# %%
# fd## represents Financial Dataset 20##
fd20.corr()
sns.pairplot(fd20)
print()

fd19.corr()
sns.pairplot(fd19)
print()

fd18.corr()
sns.pairplot(fd18)
print()

fd17.corr()
sns.pairplot(fd17)
print()

fd16.corr()
sns.pairplot(fd16)
print()

fd15.corr()
sns.pairplot(fd15)
print()

fd14.corr()
sns.pairplot(fd14)
print()

fd13.corr()
sns.pairplot(fd13)
print()

fd12.corr()
sns.pairplot(fd12)
print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18852/146675369.py in <module>
#       1 # fd## represents Financial Dataset 20##
#       2 fd20.corr()
# ----> 3 sns.pairplot(fd20)
#       4 print()
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# ...

# %%
fd20.corr()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18852/2900142946.py in <module>
#       1 fd20.corr()
# ----> 2 sns.pairplot(fd20)
#       3 print()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
# ...

# %% [markdown]
# Financial Data Plotting/Regressing

# %% [markdown]
# Quality Data Fetching/Formatting

# %% [markdown]
# Financial Data Plotting/Regressing
